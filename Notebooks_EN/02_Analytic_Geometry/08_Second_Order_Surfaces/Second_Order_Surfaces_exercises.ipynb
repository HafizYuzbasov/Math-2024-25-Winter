# %% [markdown]
# <a href="https://colab.research.google.com/github/HafizYuzbasov/Math-2024-25-Winter/blob/main/Notebooks_EN/02_Analytic_Geometry/08_Second_Order_Surfaces/Second_Order_Surfaces_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tasks related to second-order surfaces
#
# **Visualize each task.** - Python, GeoGebra, Wolfram Alpha, ...
#
# * Write the equation of a sphere with center at point $P=(1,2,3)$ and radius $r=3$.
# * Do the spheres with equations $x^2 + y^2 + z^2 = 1$ and $x^2 + y^2 + z^2 = 2$ have any common points?
# * What curve in space is formed by the intersection of the sphere $x^2 + y^2 + z^2 = 1$ with the sphere $(x-1)^2 + y^2 + z^2 = 1$? Find the equation of this curve.
# * Write the equation of the tangent plane to the paraboloid $z=(x-1)^2+y^2+1$ at point $P=(1,0,1)$.

# %% [markdown]
# TASK 1
#
#
#
#
#
#
# $$
# (x - x_0)^2 + (y - y_0)^2 + (z - z_0)^2 = r^2
# $$
#
#
#
#  $ P = (1, 2, 3) $, so $ x_0 = 1 $, $ y_0 = 2 $, and $ z_0 = 3 $.
#  $ r = 3 $.
#
#
#
# x_0 = 1 $, $ y_0 = 2 $, $ z_0 = 3 $, and $ r = 3 $
#
# $$
# (x - 1)^2 + (y - 2)^2 + (z - 3)^2 = 3^2
# $$
#
#
#
#  $ 3^2 = 9 $,
#
# $$
# (x - 1)^2 + (y - 2)^2 + (z - 3)^2 = 9
# $$
#
#
#
#  $ P = (1, 2, 3) $ and radius $ r = 3 $
#
# $$
# (x - 1)^2 + (y - 2)^2 + (z - 3)^2 = 9
# $$
#
# https://www.geogebra.org/calculator/tx8fyrt8

# %% [markdown]
# TASK 2
#
#
#
#
#
# 1. $ x^2 + y^2 + z^2 = 1 $
# 2. $ x^2 + y^2 + z^2 = 2 $
#
#
# - The first sphere, $ x^2 + y^2 + z^2 = 1 $, has its center at the origin $ (0, 0, 0) $ and a radius $ r_1 = 1 $.
# - The second sphere, $ x^2 + y^2 + z^2 = 2 $, also has its center at the origin $ (0, 0, 0) $ and a radius $ r_2 = \sqrt{2} $.
#
#
#
#
#
# $$
# x^2 + y^2 + z^2 = 1
# $$
#
# and
#
# $$
# x^2 + y^2 + z^2 = 2
# $$
# https://www.geogebra.org/calculator/equah5eu

# %% [markdown]
# TASK 3
#
#
#
#
#
# 1. $ x^2 + y^2 + z^2 = 1 $
# 2. $ (x - 1)^2 + y^2 + z^2 = 1 $
#
#
#
# $$
# (x - 1)^2 + y^2 + z^2 = 1
# $$
#
#  $ (x - 1)^2 $:
#
# $$
# (x - 1)^2 = x^2 - 2x + 1
# $$
#
#
#
# $$
# x^2 - 2x + 1 + y^2 + z^2 = 1
# $$
#
#
#
# $$
# x^2 + y^2 + z^2 - 2x + 1 = 1
# $$
#
#
#
# $$
# x^2 + y^2 + z^2 - 2x = 0
# $$
#
# Now, use the first equation $ x^2 + y^2 + z^2 = 1 $ to substitute for $ x^2 + y^2 + z^2 $
#
# $$
# 1 - 2x = 0
# $$
#
#
#
# $$
# 2x = 1 \quad \Rightarrow \quad x = \frac{1}{2}
# $$
#
#
#
# $$
# \left( \frac{1}{2} \right)^2 + y^2 + z^2 = 1
# $$
#
#
#
# $$
# \frac{1}{4} + y^2 + z^2 = 1
# $$
#
#
#
# $$
# y^2 + z^2 = \frac{3}{4}
# $$
#
#
#
#
#
#
# $$
# x = \frac{1}{2}, \quad y^2 + z^2 = \frac{3}{4}
# $$
#
# https://www.geogebra.org/calculator/vawzfgwt

# %% [markdown]
# TASK 4
#
#
#
#
#
#
# $$
# z - z_0 = f_x(x_0, y_0)(x - x_0) + f_y(x_0, y_0)(y - y_0)
# $$
#
#
#
# $$
# z = (x - 1)^2 + y^2 + 1
# $$
#
#
#
# $$
# f(x, y) = (x - 1)^2 + y^2 + 1
# $$
#
#
#
# $$
# f_x(x, y) = \frac{\partial}{\partial x} \left( (x - 1)^2 + y^2 + 1 \right) = 2(x - 1)
# $$
#
#
#
# $$
# f_y(x, y) = \frac{\partial}{\partial y} \left( (x - 1)^2 + y^2 + 1 \right) = 2y
# $$
#
#
#
# $ P = (1, 0, 1) $, $ f_x(1, 0) $
#
# $$
# f_x(1, 0) = 2(1 - 1) = 0
# $$
#
#  $ P = (1, 0, 1) $, $ f_y(1, 0) $
#
# $$
# f_y(1, 0) = 2(0) = 0
# $$
#
#
#
# $$
# z - 1 = 0(x - 1) + 0(y - 0)
# $$
#
#
#
# $$
# z - 1 = 0
# $$
#
#
#
# $$
# z = 1
# $$
#
#
#
# $$
# z = 1
# $$
#
# https://www.geogebra.org/calculator/aeqqc4fe

# %%
import numpy as np # Import the numpy library and assign it the alias 'np'
import matplotlib.pyplot as plt # Import the pyplot module from matplotlib for plotting functionalities # Moved import statement to the top

# Paraboloid function
def paraboloid(x, y):
    return (x - 1)**2 + y**2 + 1

# Create meshgrid for x, y
x = np.linspace(-2, 4, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z values for the paraboloid
Z = paraboloid(X, Y)

# Plot the paraboloid and tangent plane (z = 1)
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot paraboloid
ax.plot_surface(X, Y, Z, color='b', alpha=0.6)

# Plot tangent plane (z = 1)
Z_tangent = np.ones_like(Z)  # Tangent plane at z = 1
ax.plot_surface(X, Y, Z_tangent, color='r', alpha=0.4)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Paraboloid and Tangent Plane')

plt.show()
